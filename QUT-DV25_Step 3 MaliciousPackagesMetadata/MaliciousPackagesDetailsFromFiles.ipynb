# %% [markdown]
# <hr>
#
# ***Version: 1001.1492024.qut.cs.tnl***
#
# ***Sk Tanzir Mehedi, PhD Student, QUT***
#
# ***Supervisory Team: Prof. Raja Jurdak & Dr Chadni Islam***
# <hr>

# %% [markdown]
# **----Start of Step 2----**

# %% [markdown]
# ## Malicious Packages Summary From Files

# %%
import zipfile
import tarfile
import io

def count_setup_py_in_nested_zip(zip_file_path):
    setup_py_count = 0  # Counter for setup.py files
    outer_folder_count = 0
    package_folders_count = 0
    version_folders_count = 0
    tar_files_count = 0
    no_tar_files_count = 0
    inner_tar_read_count = 0
    no_setup_py_count = 0
    
    with zipfile.ZipFile(zip_file_path, 'r') as outer_zip:
        # List the contents of the outer zip to find the outermost folder (FolderName)
        folder_name = [name for name in outer_zip.namelist() if name.endswith('/')][0]
        outer_folder_count += 1
        print(f"Found outer folder: {folder_name}")
        
        # List the folders directly under the outer folder (PackageNameFolders)
        package_folders = [name for name in outer_zip.namelist() 
                           if name.startswith(folder_name) 
                           and name.endswith('/') 
                           and name.count('/') == folder_name.count('/') + 1]
        package_folders_count += len(package_folders)
        print(f"Package folders found: {package_folders}")
        
        # Iterate through PackageNameFolders to find VersionFolders and tar.gz or zip files
        for package_folder in package_folders:
            version_folders = [name for name in outer_zip.namelist() 
                               if name.startswith(package_folder) 
                               and name.endswith('/') 
                               and name != package_folder]
            version_folders_count += len(version_folders)
            print(f"Version folders found in {package_folder}: {version_folders}")
            
            for version_folder in version_folders:
                # Check for a .tar.gz or .zip file within the VersionFolder
                tar_files = [name for name in outer_zip.namelist() if name.startswith(version_folder) and (name.endswith('.tar.gz') or name.endswith('.zip'))]
                
                if tar_files:
                    tar_files_count += len(tar_files)
                    print(f"Compressed files found in {version_folder}: {tar_files}")
                else:
                    no_tar_files_count += 1
                    print(f"No compressed files found in {version_folder}. Skipping.")
                    continue
                
                tar_package_name = tar_files[0]
                inner_tar_read_count += 1
                print(f"Reading compressed file: {tar_package_name}")
                
                # Now, check if it's a .tar.gz or a .zip file and handle accordingly
                try:
                    with outer_zip.open(tar_package_name) as inner_file:
                        file_signature = inner_file.read(2)
                        inner_file.seek(0)  # Reset file pointer after reading signature
                        
                        if file_signature == b'\x1f\x8b':  # GZIP signature
                            try:
                                with tarfile.open(fileobj=io.BytesIO(inner_file.read()), mode='r:gz') as tar:
                                    # Find the 'setup.py' file in the tar.gz
                                    setup_py_path = [name for name in tar.getnames() if name.endswith('setup.py')]
                                    if setup_py_path:
                                        setup_py_count += 1  # Increment count when setup.py is found
                                        print(f"Found setup.py at: {setup_py_path[0]}")
                                    else:
                                        no_setup_py_count += 1
                                        print(f"No setup.py found in {tar_package_name}")
                            except tarfile.ReadError:
                                print(f"Error reading tar.gz file: {tar_package_name}. Skipping.")
                        elif file_signature == b'PK':  # ZIP signature
                            try:
                                with zipfile.ZipFile(io.BytesIO(inner_file.read()), 'r') as inner_zip:
                                    # Find the 'setup.py' file in the zip
                                    setup_py_path = [name for name in inner_zip.namelist() if name.endswith('setup.py')]
                                    if setup_py_path:
                                        setup_py_count += 1  # Increment count when setup.py is found
                                        print(f"Found setup.py at: {setup_py_path[0]}")
                                    else:
                                        no_setup_py_count += 1
                                        print(f"No setup.py found in {tar_package_name}")
                            except zipfile.BadZipFile:
                                print(f"Error reading zip file: {tar_package_name}. Skipping.")
                        else:
                            print(f"Unknown file type for {tar_package_name}. Skipping.")
                except Exception as e:
                    print(f"Error processing file {tar_package_name}: {e}")
    
    # Print the final counts for each event
    print("\nSummary:")
    print(f"Total outer folders found: {outer_folder_count}")
    print(f"Total package folders found: {package_folders_count}")
    print(f"Total version folders found: {version_folders_count}")
    print(f"Total compressed files found: {tar_files_count}")
    print(f"Total no compressed files found: {no_tar_files_count}")
    print(f"Total inner compressed files read: {inner_tar_read_count}")
    print(f"Total setup.py files found: {setup_py_count}")
    print(f"Total no setup.py files found: {no_setup_py_count}")
    
    return setup_py_count

# Provide the path to your outer zip file
zip_file_path = 'D:/Final Version/Dataset/pypi_malregistry.zip'
setup_py_count = count_setup_py_in_nested_zip(zip_file_path)
# Out:
# Found outer folder: pypi_malregistry-main/
# Package folders found: ['pypi_malregistry-main/10Cent10/', 'pypi_malregistry-main/10Cent11/', 'pypi_malregistry-main/11cent/', 'pypi_malregistry-main/12cent/', 'pypi_malregistry-main/1337c/', 'pypi_malregistry-main/1337test/', 'pypi_malregistry-main/1337z/', 'pypi_malregistry-main/13cent/', 'pypi_malregistry-main/14cent/', 'pypi_malregistry-main/15cent/', 'pypi_malregistry-main/16cent/', 'pypi_malregistry-main/1inch/', 'pypi_malregistry-main/2022-requests/', 'pypi_malregistry-main/282828282828282828/', 'pypi_malregistry-main/3m-promo-link-gen/', 'pypi_malregistry-main/3web-py/', 'pypi_malregistry-main/3web/', 'pypi_malregistry-main/4123/', 'pypi_malregistry-main/90456984689490856/', 'pypi_malregistry-main/AadhaarCrypt/', 'pypi_malregistry-main/Ailyboostbot/', 'pypi_malregistry-main/Ailynitro/', 'pypi_malregistry-main/BeaitifulSoop/', 'pypi_malregistry-main/BeaotifulSoup/', 'pypi_malregistry-main/BeaufifulSoup/', 'pypi_malregistry-main/BeautifilSoop/', 'pypi_malregistry-main/BeautifilSoup/', 'pypi_malregistry-main/BeautifolSoup/', 'pypi_malregistry-main/BeautifoulSoup/', 'pypi_malregistry-main/BeautifulSoop/', 'pypi_malregistry-main/BeautifulSoul/', 'pypi_malregistry-main/BeautifulSoup-new/', 'pypi_malregistry-main/BeautifulSoupo/', 'pypi_malregistry-main/BeautifullSoop/', 'pypi_malregistry-main/BeautifullSooup/', 'pypi_malregistry-main/BeautySoup/', 'pypi_malregistry-main/BeautyfulSoup/', 'pypi_malregistry-main/BeuatiflSoup/', 'pypi_malregistry-main/BeutifulSoop/', 'pypi_malregistry-main/BeutifullSoup/', 'pypi_malregistry-main/Crystalnitro/', 'pypi_malregistry-main/Cryztalnitro/', 'pypi_malregistry-main/Deeprce/', 'pypi_malregistry-main/DiscordSafety/', 'pypi_malregistry-main
4.tar.gz']
# Reading compressed file: pypi_malregistry-main/10Cent10/999.0.4/10Cent10-999.0.4.tar.gz
# Found setup.py at: 10Cent10-999.0.4/setup.py
# Version folders found in pypi_malregistry-main/10Cent11/: ['pypi_malregistry-main/10Cent11/999.0.4/']
# Compressed files found in pypi_malregistry-main/10Cent11/999.0.4/: ['pypi_malregistry-main/10Cent11/999.0.4/10Cent11-999.0.4.tar.gz']
# Reading compressed file: pypi_malregistry-main/10Cent11/999.0.4/10Cent11-999.0.4.tar.gz
# Found setup.py at: 10Cent11-999.0.4/setup.py
# Version folders found in pypi_malregistry-main/11cent/: ['pypi_malregistry-main/11cent/999.0.0/', 'pypi_malregistry-main/11cent/999.0.1/', 'pypi_malregistry-main/11cent/999.0.2/', 'pypi_malregistry-main/11cent/999.0.3/', 'pypi_malregistry-main/11cent/999.0.4/']
# Compressed files found in pypi_malregistry-main/11cent/999.0.0/: ['pypi_malregistry-main/11cent/999.0.0/11Cent-999.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/11cent/999.0.0/11Cent-999.0.0.tar.gz
# Found setup.py at: 11Cent-999.0.0/setup.py
# Compressed files found in pypi_malregistry-main/11cent/999.0.1/: ['pypi_malregistry-main/11cent/999.0.1/11Cent-999.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/11cent/999.0.1/11Cent-999.0.1.tar.gz
# Found setup.py at: 11Cent-999.0.1/setup.py
# Compressed files found in pypi_malregistry-main/11cent/999.0.2/: ['pypi_malregistry-main/11cent/999.0.2/11Cent-999.0.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/11cent/999.0.2/11Cent-999.0.2.tar.gz
# Found setup.py at: 11Cent-999.0.2/setup.py
# Compressed files found in pypi_malregistry-main/11cent/999.0.3/: ['pypi_malregistry-main/11cent/999.0.3/11Cent-999.0.3.tar.gz']
# Reading compressed file: pypi_malregistry-main/11cent/999.0.3/11Cent-999.0.3.tar.gz
# Found setup.py at: 11Cent-999.0.3/setup.py
# Compressed files found in pypi_malregistry-main/11cent/999.0.4/: ['pypi_malregistry-main/11cent/999.0.4/11Cent-999.0.4.tar.gz']
# Reading compressed file: pypi_malregistry-main/11cent/999.0.4/11Cent-999.0.4.tar.gz
# Found setup.py at: 11Cent-999.0.4/setup.py
# Version folders found in pypi_malregistry-main/12cent/: ['pypi_malregistry-main/12cent/999.0.0/', 'pypi_malregistry-main/12cent/999.0.1/']
# Compressed files found in pypi_malregistry-main/12cent/999.0.0/: ['pypi_malregistry-main/12cent/999.0.0/12Cent-999.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/12cent/999.0.0/12Cent-999.0.0.tar.gz
# Found setup.py at: 12Cent-999.0.0/setup.py
# Compressed files found in pypi_malregistry-main/12cent/999.0.1/: ['pypi_malregistry-main/12cent/999.0.1/12Cent-999.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/12cent/999.0.1/12Cent-999.0.1.tar.gz
# Found setup.py at: 12Cent-999.0.1/setup.py
# Version folders found in pypi_malregistry-main/1337c/: ['pypi_malregistry-main/1337c/4.4.7/']
# Compressed files found in pypi_malregistry-main/1337c/4.4.7/: ['pypi_malregistry-main/1337c/4.4.7/1337c-4.4.7.tar.gz']
# Reading compressed file: pypi_malregistry-main/1337c/4.4.7/1337c-4.4.7.tar.gz
# Found setup.py at: 1337c-4.4.7/setup.py
# Version folders found in pypi_malregistry-main/1337test/: ['pypi_malregistry-main/1337test/1/']
# Compressed files found in pypi_malregistry-main/1337test/1/: ['pypi_malregistry-main/1337test/1/1337test-1.tar.gz']
# Reading compressed file: pypi_malregistry-main/1337test/1/1337test-1.tar.gz
# Found setup.py at: 1337test-1/setup.py
# Version folders found in pypi_malregistry-main/1337z/: ['pypi_malregistry-main/1337z/4.4.7/']
# Compressed files found in pypi_malregistry-main/1337z/4.4.7/: ['pypi_malregistry-main/1337z/4.4.7/1337z-4.4.7.tar.gz']
# Reading compressed file: pypi_malregistry-main/1337z/4.4.7/1337z-4.4.7.tar.gz
# Found setup.py at: 1337z-4.4.7/setup.py
# Version folders found in pypi_malregistry-main/13cent/: ['pypi_malregistry-main/13cent/999.0.1/', 'pypi_malregistry-main/13cent/999.0.2/']
# Compressed files found in pypi_malregistry-main/13cent/999.0.1/: ['pypi_malregistry-main/13cent/999.0.1/13Cent-999.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/13cent/999.0.1/13Cent-999.0.1.tar.gz
# Found setup.py at: 13Cent-999.0.1/setup.py
# Compressed files found in pypi_malregistry-main/13cent/999.0.2/: ['pypi_malregistry-main/13cent/999.0.2/13Cent-999.0.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/13cent/999.0.2/13Cent-999.0.2.tar.gz
# Found setup.py at: 13Cent-999.0.2/setup.py
# Version folders found in pypi_malregistry-main/14cent/: ['pypi_malregistry-main/14cent/999.0.1/']
# Compressed files found in pypi_malregistry-main/14cent/999.0.1/: ['pypi_malregistry-main/14cent/999.0.1/14Cent-999.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/14cent/999.0.1/14Cent-999.0.1.tar.gz
# Found setup.py at: 14Cent-999.0.1/setup.py
# Version folders found in pypi_malregistry-main/15cent/: ['pypi_malregistry-main/15cent/999.0.1/']
# Compressed files found in pypi_malregistry-main/15cent/999.0.1/: ['pypi_malregistry-main/15cent/999.0.1/15Cent-999.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/15cent/999.0.1/15Cent-999.0.1.tar.gz
# Found setup.py at: 15Cent-999.0.1/setup.py
# Version folders found in pypi_malregistry-main/16cent/: ['pypi_malregistry-main/16cent/999.0.1/']
# Compressed files found in pypi_malregistry-main/16cent/999.0.1/: ['pypi_malregistry-main/16cent/999.0.1/16Cent-999.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/16cent/999.0.1/16Cent-999.0.1.tar.gz
# Found setup.py at: 16Cent-999.0.1/setup.py
# Version folders found in pypi_malregistry-main/1inch/: ['pypi_malregistry-main/1inch/8.6/', 'pypi_malregistry-main/1inch/8.7/', 'pypi_malregistry-main/1inch/8.9/']
# Compressed files found in pypi_malregistry-main/1inch/8.6/: ['pypi_malregistry-main/1inch/8.6/1inch-8.6.tar.gz']
# Reading compressed file: pypi_malregistry-main/1inch/8.6/1inch-8.6.tar.gz
# Found setup.py at: 1inch-8.6/setup.py
# Compressed files found in pypi_malregistry-main/1inch/8.7/: ['pypi_malregistry-main/1inch/8.7/1inch-8.7.tar.gz']
# Reading compressed file: pypi_malregistry-main/1inch/8.7/1inch-8.7.tar.gz
# Found setup.py at: 1inch-8.7/setup.py
# Compressed files found in pypi_malregistry-main/1inch/8.9/: ['pypi_malregistry-main/1inch/8.9/1inch-8.9.tar.gz']
# Reading compressed file: pypi_malregistry-main/1inch/8.9/1inch-8.9.tar.gz
# Found setup.py at: 1inch-8.9/setup.py
# Version folders found in pypi_malregistry-main/2022-requests/: ['pypi_malregistry-main/2022-requests/3.0.0/']
# Compressed files found in pypi_malregistry-main/2022-requests/3.0.0/: ['pypi_malregistry-main/2022-requests/3.0.0/2022-requests-3.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/2022-requests/3.0.0/2022-requests-3.0.0.tar.gz
# Found setup.py at: 2022-requests-3.0.0/setup.py
# Version folders found in pypi_malregistry-main/282828282828282828/: ['pypi_malregistry-main/282828282828282828/0.0.0/']
# Compressed files found in pypi_malregistry-main/282828282828282828/0.0.0/: ['pypi_malregistry-main/282828282828282828/0.0.0/282828282828282828-0.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/282828282828282828/0.0.0/282828282828282828-0.0.0.tar.gz
# Found setup.py at: 282828282828282828-0.0.0/setup.py
# Version folders found in pypi_malregistry-main/3m-promo-link-gen/: ['pypi_malregistry-main/3m-promo-link-gen/1.0/']
# Compressed files found in pypi_malregistry-main/3m-promo-link-gen/1.0/: ['pypi_malregistry-main/3m-promo-link-gen/1.0/3m-promo-link-gen-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/3m-promo-link-gen/1.0/3m-promo-link-gen-1.0.tar.gz
# Found setup.py at: 3m-promo-link-gen-1.0/setup.py
# Version folders found in pypi_malregistry-main/3web-py/: ['pypi_malregistry-main/3web-py/3web.py-1.0.0/']
# Compressed files found in pypi_malregistry-main/3web-py/3web.py-1.0.0/: ['pypi_malregistry-main/3web-py/3web.py-1.0.0/3web.py-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/3web-py/3web.py-1.0.0/3web.py-1.0.0.tar.gz
# Found setup.py at: 3web.py-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/3web/: ['pypi_malregistry-main/3web/1.0.0/']
# Compressed files found in pypi_malregistry-main/3web/1.0.0/: ['pypi_malregistry-main/3web/1.0.0/3web-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/3web/1.0.0/3web-1.0.0.tar.gz
# Found setup.py at: 3web-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/4123/: ['pypi_malregistry-main/4123/1/']
# Compressed files found in pypi_malregistry-main/4123/1/: ['pypi_malregistry-main/4123/1/4123-1-py3-none-any.tar.gz']
# Reading compressed file: pypi_malregistry-main/4123/1/4123-1-py3-none-any.tar.gz
# No setup.py found in pypi_malregistry-main/4123/1/4123-1-py3-none-any.tar.gz
# Version folders found in pypi_malregistry-main/90456984689490856/: ['pypi_malregistry-main/90456984689490856/0/']
# Compressed files found in pypi_malregistry-main/90456984689490856/0/: ['pypi_malregistry-main/90456984689490856/0/90456984689490856-0-py3-none-any.tar.gz']
# Reading compressed file: pypi_malregistry-main/90456984689490856/0/90456984689490856-0-py3-none-any.tar.gz
# No setup.py found in pypi_malregistry-main/90456984689490856/0/90456984689490856-0-py3-none-any.tar.gz
# Version folders found in pypi_malregistry-main/AadhaarCrypt/: ['pypi_malregistry-main/AadhaarCrypt/1.0/']
# Compressed files found in pypi_malregistry-main/AadhaarCrypt/1.0/: ['pypi_malregistry-main/AadhaarCrypt/1.0/AadhaarCrypt-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/AadhaarCrypt/1.0/AadhaarCrypt-1.0.tar.gz
# Found setup.py at: AadhaarCrypt-1.0/setup.py
# Version folders found in pypi_malregistry-main/Ailyboostbot/: ['pypi_malregistry-main/Ailyboostbot/1.0/']
# Compressed files found in pypi_malregistry-main/Ailyboostbot/1.0/: ['pypi_malregistry-main/Ailyboostbot/1.0/Ailyboostbot-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Ailyboostbot/1.0/Ailyboostbot-1.0.tar.gz
# Found setup.py at: Ailyboostbot-1.0/setup.py
# Version folders found in pypi_malregistry-main/Ailynitro/: ['pypi_malregistry-main/Ailynitro/1.0/']
# Compressed files found in pypi_malregistry-main/Ailynitro/1.0/: ['pypi_malregistry-main/Ailynitro/1.0/Ailynitro-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Ailynitro/1.0/Ailynitro-1.0.tar.gz
# Found setup.py at: Ailynitro-1.0/setup.py
# Version folders found in pypi_malregistry-main/BeaitifulSoop/: ['pypi_malregistry-main/BeaitifulSoop/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeaitifulSoop/1.0.0/: ['pypi_malregistry-main/BeaitifulSoop/1.0.0/BeaitifulSoop-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeaitifulSoop/1.0.0/BeaitifulSoop-1.0.0.tar.gz
# Found setup.py at: BeaitifulSoop-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeaotifulSoup/: ['pypi_malregistry-main/BeaotifulSoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeaotifulSoup/1.0.0/: ['pypi_malregistry-main/BeaotifulSoup/1.0.0/BeaotifulSoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeaotifulSoup/1.0.0/BeaotifulSoup-1.0.0.tar.gz
# Found setup.py at: BeaotifulSoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeaufifulSoup/: ['pypi_malregistry-main/BeaufifulSoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeaufifulSoup/1.0.0/: ['pypi_malregistry-main/BeaufifulSoup/1.0.0/BeaufifulSoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeaufifulSoup/1.0.0/BeaufifulSoup-1.0.0.tar.gz
# Found setup.py at: BeaufifulSoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifilSoop/: ['pypi_malregistry-main/BeautifilSoop/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifilSoop/1.0.0/: ['pypi_malregistry-main/BeautifilSoop/1.0.0/BeautifilSoop-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifilSoop/1.0.0/BeautifilSoop-1.0.0.tar.gz
# Found setup.py at: BeautifilSoop-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifilSoup/: ['pypi_malregistry-main/BeautifilSoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifilSoup/1.0.0/: ['pypi_malregistry-main/BeautifilSoup/1.0.0/BeautifilSoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifilSoup/1.0.0/BeautifilSoup-1.0.0.tar.gz
# Found setup.py at: BeautifilSoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifolSoup/: ['pypi_malregistry-main/BeautifolSoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifolSoup/1.0.0/: ['pypi_malregistry-main/BeautifolSoup/1.0.0/BeautifolSoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifolSoup/1.0.0/BeautifolSoup-1.0.0.tar.gz
# Found setup.py at: BeautifolSoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifoulSoup/: ['pypi_malregistry-main/BeautifoulSoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifoulSoup/1.0.0/: ['pypi_malregistry-main/BeautifoulSoup/1.0.0/BeautifoulSoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifoulSoup/1.0.0/BeautifoulSoup-1.0.0.tar.gz
# Found setup.py at: BeautifoulSoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifulSoop/: ['pypi_malregistry-main/BeautifulSoop/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifulSoop/1.0.0/: ['pypi_malregistry-main/BeautifulSoop/1.0.0/BeautifulSoop-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifulSoop/1.0.0/BeautifulSoop-1.0.0.tar.gz
# Found setup.py at: BeautifulSoop-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifulSoul/: ['pypi_malregistry-main/BeautifulSoul/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifulSoul/1.0.0/: ['pypi_malregistry-main/BeautifulSoul/1.0.0/BeautifulSoul-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifulSoul/1.0.0/BeautifulSoul-1.0.0.tar.gz
# Found setup.py at: BeautifulSoul-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifulSoup-new/: ['pypi_malregistry-main/BeautifulSoup-new/3.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifulSoup-new/3.0.0/: ['pypi_malregistry-main/BeautifulSoup-new/3.0.0/BeautifulSoup-new-3.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifulSoup-new/3.0.0/BeautifulSoup-new-3.0.0.tar.gz
# Found setup.py at: BeautifulSoup-new-3.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifulSoupo/: ['pypi_malregistry-main/BeautifulSoupo/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifulSoupo/1.0.0/: ['pypi_malregistry-main/BeautifulSoupo/1.0.0/BeautifulSoupo-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifulSoupo/1.0.0/BeautifulSoupo-1.0.0.tar.gz
# Found setup.py at: BeautifulSoupo-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifullSoop/: ['pypi_malregistry-main/BeautifullSoop/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifullSoop/1.0.0/: ['pypi_malregistry-main/BeautifullSoop/1.0.0/BeautifullSoop-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifullSoop/1.0.0/BeautifullSoop-1.0.0.tar.gz
# Found setup.py at: BeautifullSoop-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautifullSooup/: ['pypi_malregistry-main/BeautifullSooup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautifullSooup/1.0.0/: ['pypi_malregistry-main/BeautifullSooup/1.0.0/BeautifullSooup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautifullSooup/1.0.0/BeautifullSooup-1.0.0.tar.gz
# Found setup.py at: BeautifullSooup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautySoup/: ['pypi_malregistry-main/BeautySoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautySoup/1.0.0/: ['pypi_malregistry-main/BeautySoup/1.0.0/BeautySoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautySoup/1.0.0/BeautySoup-1.0.0.tar.gz
# Found setup.py at: BeautySoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeautyfulSoup/: ['pypi_malregistry-main/BeautyfulSoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeautyfulSoup/1.0.0/: ['pypi_malregistry-main/BeautyfulSoup/1.0.0/BeautyfulSoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeautyfulSoup/1.0.0/BeautyfulSoup-1.0.0.tar.gz
# Found setup.py at: BeautyfulSoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeuatiflSoup/: ['pypi_malregistry-main/BeuatiflSoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeuatiflSoup/1.0.0/: ['pypi_malregistry-main/BeuatiflSoup/1.0.0/BeuatiflSoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeuatiflSoup/1.0.0/BeuatiflSoup-1.0.0.tar.gz
# Found setup.py at: BeuatiflSoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeutifulSoop/: ['pypi_malregistry-main/BeutifulSoop/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeutifulSoop/1.0.0/: ['pypi_malregistry-main/BeutifulSoop/1.0.0/BeutifulSoop-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeutifulSoop/1.0.0/BeutifulSoop-1.0.0.tar.gz
# Found setup.py at: BeutifulSoop-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/BeutifullSoup/: ['pypi_malregistry-main/BeutifullSoup/1.0.0/']
# Compressed files found in pypi_malregistry-main/BeutifullSoup/1.0.0/: ['pypi_malregistry-main/BeutifullSoup/1.0.0/BeutifullSoup-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/BeutifullSoup/1.0.0/BeutifullSoup-1.0.0.tar.gz
# Found setup.py at: BeutifullSoup-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Crystalnitro/: ['pypi_malregistry-main/Crystalnitro/1.0/']
# Compressed files found in pypi_malregistry-main/Crystalnitro/1.0/: ['pypi_malregistry-main/Crystalnitro/1.0/Crystalnitro-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Crystalnitro/1.0/Crystalnitro-1.0.tar.gz
# Found setup.py at: Crystalnitro-1.0/setup.py
# Version folders found in pypi_malregistry-main/Cryztalnitro/: ['pypi_malregistry-main/Cryztalnitro/1.0/']
# Compressed files found in pypi_malregistry-main/Cryztalnitro/1.0/: ['pypi_malregistry-main/Cryztalnitro/1.0/Cryztalnitro-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Cryztalnitro/1.0/Cryztalnitro-1.0.tar.gz
# Found setup.py at: Cryztalnitro-1.0/setup.py
# Version folders found in pypi_malregistry-main/Deeprce/: ['pypi_malregistry-main/Deeprce/0.0.1/']
# Compressed files found in pypi_malregistry-main/Deeprce/0.0.1/: ['pypi_malregistry-main/Deeprce/0.0.1/Deeprce-0.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/Deeprce/0.0.1/Deeprce-0.0.1.tar.gz
# Found setup.py at: Deeprce-0.0.1/setup.py
# Version folders found in pypi_malregistry-main/DiscordSafety/: ['pypi_malregistry-main/DiscordSafety/0.1/']
# Compressed files found in pypi_malregistry-main/DiscordSafety/0.1/: ['pypi_malregistry-main/DiscordSafety/0.1/DiscordSafety-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/DiscordSafety/0.1/DiscordSafety-0.1.tar.gz
# Found setup.py at: DiscordSafety-0.1/setup.py
# Version folders found in pypi_malregistry-main/DoNotDownload/: ['pypi_malregistry-main/DoNotDownload/0.0.0/']
# Compressed files found in pypi_malregistry-main/DoNotDownload/0.0.0/: ['pypi_malregistry-main/DoNotDownload/0.0.0/DoNotDownload-0.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/DoNotDownload/0.0.0/DoNotDownload-0.0.0.tar.gz
# Found setup.py at: DoNotDownload-0.0.0/setup.py
# Version folders found in pypi_malregistry-main/EoerbIsjxqyV/: ['pypi_malregistry-main/EoerbIsjxqyV/0.3.2/']
# Compressed files found in pypi_malregistry-main/EoerbIsjxqyV/0.3.2/: ['pypi_malregistry-main/EoerbIsjxqyV/0.3.2/EoerbIsjxqyV-0.3.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/EoerbIsjxqyV/0.3.2/EoerbIsjxqyV-0.3.2.tar.gz
# Found setup.py at: EoerbIsjxqyV-0.3.2/setup.py
# Version folders found in pypi_malregistry-main/EvannLeGoat/: ['pypi_malregistry-main/EvannLeGoat/1.0.4/']
# Compressed files found in pypi_malregistry-main/EvannLeGoat/1.0.4/: ['pypi_malregistry-main/EvannLeGoat/1.0.4/EvannLeGoat-1.0.4.tar.gz']
# Reading compressed file: pypi_malregistry-main/EvannLeGoat/1.0.4/EvannLeGoat-1.0.4.tar.gz
# Found setup.py at: EvannLeGoat-1.0.4/setup.py
# Version folders found in pypi_malregistry-main/FakePipD/: ['pypi_malregistry-main/FakePipD/0.0.1/']
# Compressed files found in pypi_malregistry-main/FakePipD/0.0.1/: ['pypi_malregistry-main/FakePipD/0.0.1/FakePipD-0.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/FakePipD/0.0.1/FakePipD-0.0.1.tar.gz
# Found setup.py at: FakePipD-0.0.1/setup.py
# Version folders found in pypi_malregistry-main/ForgePy/: ['pypi_malregistry-main/ForgePy/1.0.0/', 'pypi_malregistry-main/ForgePy/1.0.1/', 'pypi_malregistry-main/ForgePy/1.0.2/', 'pypi_malregistry-main/ForgePy/1.0.3/']
# Compressed files found in pypi_malregistry-main/ForgePy/1.0.0/: ['pypi_malregistry-main/ForgePy/1.0.0/ForgePy-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/ForgePy/1.0.0/ForgePy-1.0.0.tar.gz
# Found setup.py at: ForgePy-1.0.0/setup.py
# Compressed files found in pypi_malregistry-main/ForgePy/1.0.1/: ['pypi_malregistry-main/ForgePy/1.0.1/ForgePy-1.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ForgePy/1.0.1/ForgePy-1.0.1.tar.gz
# Found setup.py at: ForgePy-1.0.1/setup.py
# Compressed files found in pypi_malregistry-main/ForgePy/1.0.2/: ['pypi_malregistry-main/ForgePy/1.0.2/ForgePy-1.0.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/ForgePy/1.0.2/ForgePy-1.0.2.tar.gz
# Found setup.py at: ForgePy-1.0.2/setup.py
# Compressed files found in pypi_malregistry-main/ForgePy/1.0.3/: ['pypi_malregistry-main/ForgePy/1.0.3/ForgePy-1.0.3.tar.gz']
# Reading compressed file: pypi_malregistry-main/ForgePy/1.0.3/ForgePy-1.0.3.tar.gz
# Found setup.py at: ForgePy-1.0.3/setup.py
# Version folders found in pypi_malregistry-main/ForgePys/: ['pypi_malregistry-main/ForgePys/1.0.3/']
# Compressed files found in pypi_malregistry-main/ForgePys/1.0.3/: ['pypi_malregistry-main/ForgePys/1.0.3/ForgePys-1.0.3.tar.gz']
# Reading compressed file: pypi_malregistry-main/ForgePys/1.0.3/ForgePys-1.0.3.tar.gz
# Found setup.py at: ForgePys-1.0.3/setup.py
# Version folders found in pypi_malregistry-main/ForgyP/: ['pypi_malregistry-main/ForgyP/1.0.3/']
# Compressed files found in pypi_malregistry-main/ForgyP/1.0.3/: ['pypi_malregistry-main/ForgyP/1.0.3/ForgyP-1.0.3.tar.gz']
# Reading compressed file: pypi_malregistry-main/ForgyP/1.0.3/ForgyP-1.0.3.tar.gz
# Found setup.py at: ForgyP-1.0.3/setup.py
# Version folders found in pypi_malregistry-main/ForgyPs/: ['pypi_malregistry-main/ForgyPs/2.0.0/']
# Compressed files found in pypi_malregistry-main/ForgyPs/2.0.0/: ['pypi_malregistry-main/ForgyPs/2.0.0/ForgyPs-2.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/ForgyPs/2.0.0/ForgyPs-2.0.0.tar.gz
# Found setup.py at: ForgyPs-2.0.0/setup.py
# Version folders found in pypi_malregistry-main/HTTPRequesting/: ['pypi_malregistry-main/HTTPRequesting/1.1.1/', 'pypi_malregistry-main/HTTPRequesting/3.0.1/']
# Compressed files found in pypi_malregistry-main/HTTPRequesting/1.1.1/: ['pypi_malregistry-main/HTTPRequesting/1.1.1/httprequesting-1.1.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/HTTPRequesting/1.1.1/httprequesting-1.1.1.tar.gz
# No setup.py found in pypi_malregistry-main/HTTPRequesting/1.1.1/httprequesting-1.1.1.tar.gz
# Compressed files found in pypi_malregistry-main/HTTPRequesting/3.0.1/: ['pypi_malregistry-main/HTTPRequesting/3.0.1/HTTPRequesting-3.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/HTTPRequesting/3.0.1/HTTPRequesting-3.0.1.tar.gz
# Found setup.py at: HTTPRequesting-3.0.1/setup.py
# Version folders found in pypi_malregistry-main/HakePip/: ['pypi_malregistry-main/HakePip/0.1.1/']
# Compressed files found in pypi_malregistry-main/HakePip/0.1.1/: ['pypi_malregistry-main/HakePip/0.1.1/HakePip-0.1.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/HakePip/0.1.1/HakePip-0.1.1.tar.gz
# Found setup.py at: HakePip-0.1.1/setup.py
# Version folders found in pypi_malregistry-main/IncapError/: ['pypi_malregistry-main/IncapError/7.0.0/']
# Compressed files found in pypi_malregistry-main/IncapError/7.0.0/: ['pypi_malregistry-main/IncapError/7.0.0/IncapError-7.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/IncapError/7.0.0/IncapError-7.0.0.tar.gz
# Found setup.py at: IncapError-7.0.0/setup.py
# Version folders found in pypi_malregistry-main/Lukz/: ['pypi_malregistry-main/Lukz/2.0.0/', 'pypi_malregistry-main/Lukz/2.0.1/', 'pypi_malregistry-main/Lukz/3.0.0/']
# Compressed files found in pypi_malregistry-main/Lukz/2.0.0/: ['pypi_malregistry-main/Lukz/2.0.0/Lukz-2.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Lukz/2.0.0/Lukz-2.0.0.tar.gz
# Found setup.py at: Lukz-2.0.0/setup.py
# Compressed files found in pypi_malregistry-main/Lukz/2.0.1/: ['pypi_malregistry-main/Lukz/2.0.1/Lukz-2.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/Lukz/2.0.1/Lukz-2.0.1.tar.gz
# Found setup.py at: Lukz-2.0.1/setup.py
# Compressed files found in pypi_malregistry-main/Lukz/3.0.0/: ['pypi_malregistry-main/Lukz/3.0.0/Lukz-3.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Lukz/3.0.0/Lukz-3.0.0.tar.gz
# Found setup.py at: Lukz-3.0.0/setup.py
# Version folders found in pypi_malregistry-main/MJpoYTWNgddh/: ['pypi_malregistry-main/MJpoYTWNgddh/0.3.2/']
# Compressed files found in pypi_malregistry-main/MJpoYTWNgddh/0.3.2/: ['pypi_malregistry-main/MJpoYTWNgddh/0.3.2/MJpoYTWNgddh-0.3.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/MJpoYTWNgddh/0.3.2/MJpoYTWNgddh-0.3.2.tar.gz
# Found setup.py at: MJpoYTWNgddh-0.3.2/setup.py
# Version folders found in pypi_malregistry-main/Maptplotlib/: ['pypi_malregistry-main/Maptplotlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Maptplotlib/1.0.0/: ['pypi_malregistry-main/Maptplotlib/1.0.0/Maptplotlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Maptplotlib/1.0.0/Maptplotlib-1.0.0.tar.gz
# Found setup.py at: Maptplotlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplftlib/: ['pypi_malregistry-main/Matplftlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplftlib/1.0.0/: ['pypi_malregistry-main/Matplftlib/1.0.0/Matplftlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplftlib/1.0.0/Matplftlib-1.0.0.tar.gz
# Found setup.py at: Matplftlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matpliotlib/: ['pypi_malregistry-main/Matpliotlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matpliotlib/1.0.0/: ['pypi_malregistry-main/Matpliotlib/1.0.0/Matpliotlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matpliotlib/1.0.0/Matpliotlib-1.0.0.tar.gz
# Found setup.py at: Matpliotlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplkotlib/: ['pypi_malregistry-main/Matplkotlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplkotlib/1.0.0/: ['pypi_malregistry-main/Matplkotlib/1.0.0/Matplkotlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplkotlib/1.0.0/Matplkotlib-1.0.0.tar.gz
# Found setup.py at: Matplkotlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matpllotib/: ['pypi_malregistry-main/Matpllotib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matpllotib/1.0.0/: ['pypi_malregistry-main/Matpllotib/1.0.0/Matpllotib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matpllotib/1.0.0/Matpllotib-1.0.0.tar.gz
# Found setup.py at: Matpllotib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplolplib/: ['pypi_malregistry-main/Matplolplib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplolplib/1.0.0/: ['pypi_malregistry-main/Matplolplib/1.0.0/Matplolplib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplolplib/1.0.0/Matplolplib-1.0.0.tar.gz
# Found setup.py at: Matplolplib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matploltlab/: ['pypi_malregistry-main/Matploltlab/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matploltlab/1.0.0/: ['pypi_malregistry-main/Matploltlab/1.0.0/Matploltlab-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matploltlab/1.0.0/Matploltlab-1.0.0.tar.gz
# Found setup.py at: Matploltlab-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matploltlib/: ['pypi_malregistry-main/Matploltlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matploltlib/1.0.0/: ['pypi_malregistry-main/Matploltlib/1.0.0/Matploltlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matploltlib/1.0.0/Matploltlib-1.0.0.tar.gz
# Found setup.py at: Matploltlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplootib/: ['pypi_malregistry-main/Matplootib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplootib/1.0.0/: ['pypi_malregistry-main/Matplootib/1.0.0/Matplootib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplootib/1.0.0/Matplootib-1.0.0.tar.gz
# Found setup.py at: Matplootib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplorlib/: ['pypi_malregistry-main/Matplorlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplorlib/1.0.0/: ['pypi_malregistry-main/Matplorlib/1.0.0/Matplorlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplorlib/1.0.0/Matplorlib-1.0.0.tar.gz
# Found setup.py at: Matplorlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotblib/: ['pypi_malregistry-main/Matplotblib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotblib/1.0.0/: ['pypi_malregistry-main/Matplotblib/1.0.0/Matplotblib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotblib/1.0.0/Matplotblib-1.0.0.tar.gz
# Found setup.py at: Matplotblib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotib/: ['pypi_malregistry-main/Matplotib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotib/1.0.0/: ['pypi_malregistry-main/Matplotib/1.0.0/Matplotib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotib/1.0.0/Matplotib-1.0.0.tar.gz
# Found setup.py at: Matplotib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotkib/: ['pypi_malregistry-main/Matplotkib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotkib/1.0.0/: ['pypi_malregistry-main/Matplotkib/1.0.0/Matplotkib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotkib/1.0.0/Matplotkib-1.0.0.tar.gz
# Found setup.py at: Matplotkib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotklib/: ['pypi_malregistry-main/Matplotklib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotklib/1.0.0/: ['pypi_malregistry-main/Matplotklib/1.0.0/Matplotklib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotklib/1.0.0/Matplotklib-1.0.0.tar.gz
# Found setup.py at: Matplotklib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotllib/: ['pypi_malregistry-main/Matplotllib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotllib/1.0.0/: ['pypi_malregistry-main/Matplotllib/1.0.0/Matplotllib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotllib/1.0.0/Matplotllib-1.0.0.tar.gz
# Found setup.py at: Matplotllib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotlob/: ['pypi_malregistry-main/Matplotlob/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotlob/1.0.0/: ['pypi_malregistry-main/Matplotlob/1.0.0/Matplotlob-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotlob/1.0.0/Matplotlob-1.0.0.tar.gz
# Found setup.py at: Matplotlob-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotlpib/: ['pypi_malregistry-main/Matplotlpib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotlpib/1.0.0/: ['pypi_malregistry-main/Matplotlpib/1.0.0/Matplotlpib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotlpib/1.0.0/Matplotlpib-1.0.0.tar.gz
# Found setup.py at: Matplotlpib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotlr/: ['pypi_malregistry-main/Matplotlr/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotlr/1.0.0/: ['pypi_malregistry-main/Matplotlr/1.0.0/Matplotlr-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotlr/1.0.0/Matplotlr-1.0.0.tar.gz
# Found setup.py at: Matplotlr-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotoib/: ['pypi_malregistry-main/Matplotoib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotoib/1.0.0/: ['pypi_malregistry-main/Matplotoib/1.0.0/Matplotoib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotoib/1.0.0/Matplotoib-1.0.0.tar.gz
# Found setup.py at: Matplotoib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplottbib/: ['pypi_malregistry-main/Matplottbib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplottbib/1.0.0/: ['pypi_malregistry-main/Matplottbib/1.0.0/Matplottbib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplottbib/1.0.0/Matplottbib-1.0.0.tar.gz
# Found setup.py at: Matplottbib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplottib/: ['pypi_malregistry-main/Matplottib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplottib/1.0.0/: ['pypi_malregistry-main/Matplottib/1.0.0/Matplottib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplottib/1.0.0/Matplottib-1.0.0.tar.gz
# Found setup.py at: Matplottib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplottlab/: ['pypi_malregistry-main/Matplottlab/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplottlab/1.0.0/: ['pypi_malregistry-main/Matplottlab/1.0.0/Matplottlab-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplottlab/1.0.0/Matplottlab-1.0.0.tar.gz
# Found setup.py at: Matplottlab-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotvib/: ['pypi_malregistry-main/Matplotvib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotvib/1.0.0/: ['pypi_malregistry-main/Matplotvib/1.0.0/Matplotvib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotvib/1.0.0/Matplotvib-1.0.0.tar.gz
# Found setup.py at: Matplotvib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplotvlib/: ['pypi_malregistry-main/Matplotvlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplotvlib/1.0.0/: ['pypi_malregistry-main/Matplotvlib/1.0.0/Matplotvlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplotvlib/1.0.0/Matplotvlib-1.0.0.tar.gz
# Found setup.py at: Matplotvlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplrtlib/: ['pypi_malregistry-main/Matplrtlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplrtlib/1.0.0/: ['pypi_malregistry-main/Matplrtlib/1.0.0/Matplrtlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplrtlib/1.0.0/Matplrtlib-1.0.0.tar.gz
# Found setup.py at: Matplrtlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matpltotlib/: ['pypi_malregistry-main/Matpltotlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matpltotlib/1.0.0/: ['pypi_malregistry-main/Matpltotlib/1.0.0/Matpltotlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matpltotlib/1.0.0/Matpltotlib-1.0.0.tar.gz
# Found setup.py at: Matpltotlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Matplttlib/: ['pypi_malregistry-main/Matplttlib/1.0.0/']
# Compressed files found in pypi_malregistry-main/Matplttlib/1.0.0/: ['pypi_malregistry-main/Matplttlib/1.0.0/Matplttlib-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/Matplttlib/1.0.0/Matplttlib-1.0.0.tar.gz
# Found setup.py at: Matplttlib-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/NP6HelperHttper/: ['pypi_malregistry-main/NP6HelperHttper/0.1/']
# Compressed files found in pypi_malregistry-main/NP6HelperHttper/0.1/: ['pypi_malregistry-main/NP6HelperHttper/0.1/NP6HelperHttper-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/NP6HelperHttper/0.1/NP6HelperHttper-0.1.tar.gz
# Found setup.py at: NP6HelperHttper-0.1/setup.py
# Version folders found in pypi_malregistry-main/NP6HelperHttptest/: ['pypi_malregistry-main/NP6HelperHttptest/0.4/', 'pypi_malregistry-main/NP6HelperHttptest/0.5/', 'pypi_malregistry-main/NP6HelperHttptest/0.6/']
# Compressed files found in pypi_malregistry-main/NP6HelperHttptest/0.4/: ['pypi_malregistry-main/NP6HelperHttptest/0.4/NP6HelperHttptest-0.4.tar.gz']
# Reading compressed file: pypi_malregistry-main/NP6HelperHttptest/0.4/NP6HelperHttptest-0.4.tar.gz
# Found setup.py at: NP6HelperHttptest-0.4/setup.py
# Compressed files found in pypi_malregistry-main/NP6HelperHttptest/0.5/: ['pypi_malregistry-main/NP6HelperHttptest/0.5/NP6HelperHttptest-0.5.tar.gz']
# Reading compressed file: pypi_malregistry-main/NP6HelperHttptest/0.5/NP6HelperHttptest-0.5.tar.gz
# Found setup.py at: NP6HelperHttptest-0.5/setup.py
# Compressed files found in pypi_malregistry-main/NP6HelperHttptest/0.6/: ['pypi_malregistry-main/NP6HelperHttptest/0.6/NP6HelperHttptest-0.6.tar.gz']
# Reading compressed file: pypi_malregistry-main/NP6HelperHttptest/0.6/NP6HelperHttptest-0.6.tar.gz
# Found setup.py at: NP6HelperHttptest-0.6/setup.py
# Version folders found in pypi_malregistry-main/PakePip/: ['pypi_malregistry-main/PakePip/0.1.2/']
# Compressed files found in pypi_malregistry-main/PakePip/0.1.2/: ['pypi_malregistry-main/PakePip/0.1.2/PakePip-0.1.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/PakePip/0.1.2/PakePip-0.1.2.tar.gz
# Found setup.py at: PakePip-0.1.2/setup.py
# Version folders found in pypi_malregistry-main/PandasProx/: ['pypi_malregistry-main/PandasProx/1.0.1/']
# Compressed files found in pypi_malregistry-main/PandasProx/1.0.1/: ['pypi_malregistry-main/PandasProx/1.0.1/PandasProx-1.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/PandasProx/1.0.1/PandasProx-1.0.1.tar.gz
# Found setup.py at: PandasProx-1.0.1/setup.py
# Version folders found in pypi_malregistry-main/PqTorch/: ['pypi_malregistry-main/PqTorch/1.0.0/']
# Compressed files found in pypi_malregistry-main/PqTorch/1.0.0/: ['pypi_malregistry-main/PqTorch/1.0.0/PqTorch-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PqTorch/1.0.0/PqTorch-1.0.0.tar.gz
# Found setup.py at: PqTorch-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/Print-django/: ['pypi_malregistry-main/Print-django/3.9.10/']
# Compressed files found in pypi_malregistry-main/Print-django/3.9.10/: ['pypi_malregistry-main/Print-django/3.9.10/Print-django-3.9.10.tar.gz']
# Reading compressed file: pypi_malregistry-main/Print-django/3.9.10/Print-django-3.9.10.tar.gz
# Found setup.py at: Print-django-3.9.10/setup.py
# Version folders found in pypi_malregistry-main/Print-pip/: ['pypi_malregistry-main/Print-pip/13.9.3/']
# Compressed files found in pypi_malregistry-main/Print-pip/13.9.3/: ['pypi_malregistry-main/Print-pip/13.9.3/Print-pip-13.9.3.tar.gz']
# Reading compressed file: pypi_malregistry-main/Print-pip/13.9.3/Print-pip-13.9.3.tar.gz
# Found setup.py at: Print-pip-13.9.3/setup.py
# Version folders found in pypi_malregistry-main/Print-requests/: ['pypi_malregistry-main/Print-requests/13.18.4/']
# Compressed files found in pypi_malregistry-main/Print-requests/13.18.4/: ['pypi_malregistry-main/Print-requests/13.18.4/Print-requests-13.18.4.tar.gz']
# Reading compressed file: pypi_malregistry-main/Print-requests/13.18.4/Print-requests-13.18.4.tar.gz
# Found setup.py at: Print-requests-13.18.4/setup.py
# Version folders found in pypi_malregistry-main/PyGacme/: ['pypi_malregistry-main/PyGacme/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGacme/1.0.0/: ['pypi_malregistry-main/PyGacme/1.0.0/PyGacme-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGacme/1.0.0/PyGacme-1.0.0.tar.gz
# Found setup.py at: PyGacme-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGaeme/: ['pypi_malregistry-main/PyGaeme/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGaeme/1.0.0/: ['pypi_malregistry-main/PyGaeme/1.0.0/PyGaeme-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGaeme/1.0.0/PyGaeme-1.0.0.tar.gz
# Found setup.py at: PyGaeme-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGamne/: ['pypi_malregistry-main/PyGamne/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGamne/1.0.0/: ['pypi_malregistry-main/PyGamne/1.0.0/PyGamne-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGamne/1.0.0/PyGamne-1.0.0.tar.gz
# Found setup.py at: PyGamne-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGamr/: ['pypi_malregistry-main/PyGamr/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGamr/1.0.0/: ['pypi_malregistry-main/PyGamr/1.0.0/PyGamr-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGamr/1.0.0/PyGamr-1.0.0.tar.gz
# Found setup.py at: PyGamr-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGamse/: ['pypi_malregistry-main/PyGamse/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGamse/1.0.0/: ['pypi_malregistry-main/PyGamse/1.0.0/PyGamse-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGamse/1.0.0/PyGamse-1.0.0.tar.gz
# Found setup.py at: PyGamse-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGamw/: ['pypi_malregistry-main/PyGamw/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGamw/1.0.0/: ['pypi_malregistry-main/PyGamw/1.0.0/PyGamw-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGamw/1.0.0/PyGamw-1.0.0.tar.gz
# Found setup.py at: PyGamw-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGane/: ['pypi_malregistry-main/PyGane/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGane/1.0.0/: ['pypi_malregistry-main/PyGane/1.0.0/PyGane-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGane/1.0.0/PyGane-1.0.0.tar.gz
# Found setup.py at: PyGane-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGaome/: ['pypi_malregistry-main/PyGaome/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGaome/1.0.0/: ['pypi_malregistry-main/PyGaome/1.0.0/PyGaome-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGaome/1.0.0/PyGaome-1.0.0.tar.gz
# Found setup.py at: PyGaome-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGaqme/: ['pypi_malregistry-main/PyGaqme/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGaqme/1.0.0/: ['pypi_malregistry-main/PyGaqme/1.0.0/PyGaqme-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGaqme/1.0.0/PyGaqme-1.0.0.tar.gz
# Found setup.py at: PyGaqme-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGarme/: ['pypi_malregistry-main/PyGarme/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGarme/1.0.0/: ['pypi_malregistry-main/PyGarme/1.0.0/PyGarme-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGarme/1.0.0/PyGarme-1.0.0.tar.gz
# Found setup.py at: PyGarme-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGawme/: ['pypi_malregistry-main/PyGawme/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGawme/1.0.0/: ['pypi_malregistry-main/PyGawme/1.0.0/PyGawme-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGawme/1.0.0/PyGawme-1.0.0.tar.gz
# Found setup.py at: PyGawme-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGazme/: ['pypi_malregistry-main/PyGazme/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGazme/1.0.0/: ['pypi_malregistry-main/PyGazme/1.0.0/PyGazme-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGazme/1.0.0/PyGazme-1.0.0.tar.gz
# Found setup.py at: PyGazme-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGfme/: ['pypi_malregistry-main/PyGfme/1.0.0/']
# Compressed files found in pypi_malregistry-main/PyGfme/1.0.0/: ['pypi_malregistry-main/PyGfme/1.0.0/PyGfme-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/PyGfme/1.0.0/PyGfme-1.0.0.tar.gz
# Found setup.py at: PyGfme-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/PyGmme/: ['pypi_malregistry-main/PyGmme/1.0.0/']
# ...
# Found setup.py at: yfinnce-0.1/setup.py
# Version folders found in pypi_malregistry-main/yfnance/: ['pypi_malregistry-main/yfnance/0.1/']
# Compressed files found in pypi_malregistry-main/yfnance/0.1/: ['pypi_malregistry-main/yfnance/0.1/yfnance-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/yfnance/0.1/yfnance-0.1.tar.gz
# Found setup.py at: yfnance-0.1/setup.py
# Version folders found in pypi_malregistry-main/yfniance/: ['pypi_malregistry-main/yfniance/0.1/']
# Compressed files found in pypi_malregistry-main/yfniance/0.1/: ['pypi_malregistry-main/yfniance/0.1/yfniance-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/yfniance/0.1/yfniance-0.1.tar.gz
# Found setup.py at: yfniance-0.1/setup.py
# Version folders found in pypi_malregistry-main/ygame/: ['pypi_malregistry-main/ygame/0.1/']
# Compressed files found in pypi_malregistry-main/ygame/0.1/: ['pypi_malregistry-main/ygame/0.1/ygame-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ygame/0.1/ygame-0.1.tar.gz
# Found setup.py at: ygame-0.1/setup.py
# Version folders found in pypi_malregistry-main/yiffparty/: ['pypi_malregistry-main/yiffparty/0.01/', 'pypi_malregistry-main/yiffparty/0.02/', 'pypi_malregistry-main/yiffparty/0.03/', 'pypi_malregistry-main/yiffparty/0.04/', 'pypi_malregistry-main/yiffparty/0.05/']
# Compressed files found in pypi_malregistry-main/yiffparty/0.01/: ['pypi_malregistry-main/yiffparty/0.01/yiffparty-0.01.tar.gz']
# Reading compressed file: pypi_malregistry-main/yiffparty/0.01/yiffparty-0.01.tar.gz
# Found setup.py at: yiffparty-0.01/setup.py
# Compressed files found in pypi_malregistry-main/yiffparty/0.02/: ['pypi_malregistry-main/yiffparty/0.02/yiffparty-0.02.tar.gz']
# Reading compressed file: pypi_malregistry-main/yiffparty/0.02/yiffparty-0.02.tar.gz
# Found setup.py at: yiffparty-0.02/setup.py
# Compressed files found in pypi_malregistry-main/yiffparty/0.03/: ['pypi_malregistry-main/yiffparty/0.03/yiffparty-0.03.tar.gz']
# Reading compressed file: pypi_malregistry-main/yiffparty/0.03/yiffparty-0.03.tar.gz
# Found setup.py at: yiffparty-0.03/setup.py
# Compressed files found in pypi_malregistry-main/yiffparty/0.04/: ['pypi_malregistry-main/yiffparty/0.04/yiffparty-0.04.tar.gz']
# Reading compressed file: pypi_malregistry-main/yiffparty/0.04/yiffparty-0.04.tar.gz
# Found setup.py at: yiffparty-0.04/setup.py
# Compressed files found in pypi_malregistry-main/yiffparty/0.05/: ['pypi_malregistry-main/yiffparty/0.05/yiffparty-0.05.tar.gz']
# Reading compressed file: pypi_malregistry-main/yiffparty/0.05/yiffparty-0.05.tar.gz
# Found setup.py at: yiffparty-0.05/setup.py
# Version folders found in pypi_malregistry-main/yinance/: ['pypi_malregistry-main/yinance/4.5.2/']
# Compressed files found in pypi_malregistry-main/yinance/4.5.2/: ['pypi_malregistry-main/yinance/4.5.2/yinance-4.5.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/yinance/4.5.2/yinance-4.5.2.tar.gz
# Found setup.py at: yinance-4.5.2/setup.py
# Version folders found in pypi_malregistry-main/yinstaller/: ['pypi_malregistry-main/yinstaller/4.5.2/']
# Compressed files found in pypi_malregistry-main/yinstaller/4.5.2/: ['pypi_malregistry-main/yinstaller/4.5.2/yinstaller-4.5.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/yinstaller/4.5.2/yinstaller-4.5.2.tar.gz
# Found setup.py at: yinstaller-4.5.2/setup.py
# Version folders found in pypi_malregistry-main/ymongo/: ['pypi_malregistry-main/ymongo/4.4.7/']
# Compressed files found in pypi_malregistry-main/ymongo/4.4.7/: ['pypi_malregistry-main/ymongo/4.4.7/ymongo-4.4.7.tar.gz']
# Reading compressed file: pypi_malregistry-main/ymongo/4.4.7/ymongo-4.4.7.tar.gz
# Found setup.py at: ymongo-4.4.7/setup.py
# Version folders found in pypi_malregistry-main/yocolor/: ['pypi_malregistry-main/yocolor/0.4.6/']
# Compressed files found in pypi_malregistry-main/yocolor/0.4.6/: ['pypi_malregistry-main/yocolor/0.4.6/yocolor-0.4.6.tar.gz']
# Reading compressed file: pypi_malregistry-main/yocolor/0.4.6/yocolor-0.4.6.tar.gz
# Found setup.py at: yocolor-0.4.6/setup.py
# Version folders found in pypi_malregistry-main/yohewoasaw/: ['pypi_malregistry-main/yohewoasaw/0.0.0/']
# Compressed files found in pypi_malregistry-main/yohewoasaw/0.0.0/: ['pypi_malregistry-main/yohewoasaw/0.0.0/yohewoasaw-0.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/yohewoasaw/0.0.0/yohewoasaw-0.0.0.tar.gz
# Found setup.py at: yohewoasaw-0.0.0/setup.py
# Version folders found in pypi_malregistry-main/youhans/: ['pypi_malregistry-main/youhans/1.0.0/']
# Compressed files found in pypi_malregistry-main/youhans/1.0.0/: ['pypi_malregistry-main/youhans/1.0.0/youhans-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/youhans/1.0.0/youhans-1.0.0.tar.gz
# Found setup.py at: youhans-1.0.0.tar.gz/setup.py
# Version folders found in pypi_malregistry-main/youtube-new/: ['pypi_malregistry-main/youtube-new/2.2.1/']
# Compressed files found in pypi_malregistry-main/youtube-new/2.2.1/: ['pypi_malregistry-main/youtube-new/2.2.1/youtube-new-2.2.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/youtube-new/2.2.1/youtube-new-2.2.1.tar.gz
# Found setup.py at: youtube-new-2.2.1/setup.py
# Version folders found in pypi_malregistry-main/ypcodestyle/: ['pypi_malregistry-main/ypcodestyle/0.1/']
# Compressed files found in pypi_malregistry-main/ypcodestyle/0.1/: ['pypi_malregistry-main/ypcodestyle/0.1/ypcodestyle-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ypcodestyle/0.1/ypcodestyle-0.1.tar.gz
# Found setup.py at: ypcodestyle-0.1/setup.py
# Version folders found in pypi_malregistry-main/yper/: ['pypi_malregistry-main/yper/0.1/']
# Compressed files found in pypi_malregistry-main/yper/0.1/: ['pypi_malregistry-main/yper/0.1/yper-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/yper/0.1/yper-0.1.tar.gz
# Found setup.py at: yper-0.1/setup.py
# Version folders found in pypi_malregistry-main/ypinstaller/: ['pypi_malregistry-main/ypinstaller/0.1/']
# Compressed files found in pypi_malregistry-main/ypinstaller/0.1/: ['pypi_malregistry-main/ypinstaller/0.1/ypinstaller-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ypinstaller/0.1/ypinstaller-0.1.tar.gz
# Found setup.py at: ypinstaller-0.1/setup.py
# Version folders found in pypi_malregistry-main/ypsocks/: ['pypi_malregistry-main/ypsocks/0.1/']
# Compressed files found in pypi_malregistry-main/ypsocks/0.1/: ['pypi_malregistry-main/ypsocks/0.1/ypsocks-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ypsocks/0.1/ypsocks-0.1.tar.gz
# Found setup.py at: ypsocks-0.1/setup.py
# Version folders found in pypi_malregistry-main/ypthon-binance/: ['pypi_malregistry-main/ypthon-binance/0.1/']
# Compressed files found in pypi_malregistry-main/ypthon-binance/0.1/: ['pypi_malregistry-main/ypthon-binance/0.1/ypthon-binance-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ypthon-binance/0.1/ypthon-binance-0.1.tar.gz
# Found setup.py at: ypthon-binance-0.1/setup.py
# Version folders found in pypi_malregistry-main/yptt/: ['pypi_malregistry-main/yptt/4.4.7/']
# Compressed files found in pypi_malregistry-main/yptt/4.4.7/: ['pypi_malregistry-main/yptt/4.4.7/yptt-4.4.7.tar.gz']
# Reading compressed file: pypi_malregistry-main/yptt/4.4.7/yptt-4.4.7.tar.gz
# Found setup.py at: yptt-4.4.7/setup.py
# Version folders found in pypi_malregistry-main/ysocks/: ['pypi_malregistry-main/ysocks/0.1/']
# Compressed files found in pypi_malregistry-main/ysocks/0.1/: ['pypi_malregistry-main/ysocks/0.1/ysocks-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ysocks/0.1/ysocks-0.1.tar.gz
# Found setup.py at: ysocks-0.1/setup.py
# Version folders found in pypi_malregistry-main/ython-binance/: ['pypi_malregistry-main/ython-binance/0.1/']
# Compressed files found in pypi_malregistry-main/ython-binance/0.1/: ['pypi_malregistry-main/ython-binance/0.1/ython-binance-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ython-binance/0.1/ython-binance-0.1.tar.gz
# Found setup.py at: ython-binance-0.1/setup.py
# Version folders found in pypi_malregistry-main/ytorch/: ['pypi_malregistry-main/ytorch/0.1/']
# Compressed files found in pypi_malregistry-main/ytorch/0.1/: ['pypi_malregistry-main/ytorch/0.1/ytorch-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/ytorch/0.1/ytorch-0.1.tar.gz
# Found setup.py at: ytorch-0.1/setup.py
# Version folders found in pypi_malregistry-main/yvper/: ['pypi_malregistry-main/yvper/0.1/']
# Compressed files found in pypi_malregistry-main/yvper/0.1/: ['pypi_malregistry-main/yvper/0.1/yvper-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/yvper/0.1/yvper-0.1.tar.gz
# Found setup.py at: yvper-0.1/setup.py
# Version folders found in pypi_malregistry-main/ywin32/: ['pypi_malregistry-main/ywin32/4.5.2/']
# Compressed files found in pypi_malregistry-main/ywin32/4.5.2/: ['pypi_malregistry-main/ywin32/4.5.2/ywin32-4.5.2.tar.gz']
# Reading compressed file: pypi_malregistry-main/ywin32/4.5.2/ywin32-4.5.2.tar.gz
# Found setup.py at: ywin32-4.5.2/setup.py
# Version folders found in pypi_malregistry-main/yyfinance/: ['pypi_malregistry-main/yyfinance/0.1/']
# Compressed files found in pypi_malregistry-main/yyfinance/0.1/: ['pypi_malregistry-main/yyfinance/0.1/yyfinance-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/yyfinance/0.1/yyfinance-0.1.tar.gz
# Found setup.py at: yyfinance-0.1/setup.py
# Version folders found in pypi_malregistry-main/zafira/: ['pypi_malregistry-main/zafira/0.1/']
# Compressed files found in pypi_malregistry-main/zafira/0.1/: ['pypi_malregistry-main/zafira/0.1/zafira-0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/zafira/0.1/zafira-0.1.tar.gz
# Found setup.py at: zafira-0.1/setup.py
# Version folders found in pypi_malregistry-main/zefkopzekfo/: ['pypi_malregistry-main/zefkopzekfo/0.0.1/']
# Compressed files found in pypi_malregistry-main/zefkopzekfo/0.0.1/: ['pypi_malregistry-main/zefkopzekfo/0.0.1/zefkopzekfo-0.0.1-py3-none-any.tar.gz']
# Reading compressed file: pypi_malregistry-main/zefkopzekfo/0.0.1/zefkopzekfo-0.0.1-py3-none-any.tar.gz
# No setup.py found in pypi_malregistry-main/zefkopzekfo/0.0.1/zefkopzekfo-0.0.1-py3-none-any.tar.gz
# Version folders found in pypi_malregistry-main/zelixnitro/: ['pypi_malregistry-main/zelixnitro/1.0/']
# Compressed files found in pypi_malregistry-main/zelixnitro/1.0/: ['pypi_malregistry-main/zelixnitro/1.0/zelixnitro-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/zelixnitro/1.0/zelixnitro-1.0.tar.gz
# Found setup.py at: zelixnitro-1.0.tar.gz/setup.py
# Version folders found in pypi_malregistry-main/zeubilamouche/: ['pypi_malregistry-main/zeubilamouche/0.1.4/']
# Compressed files found in pypi_malregistry-main/zeubilamouche/0.1.4/: ['pypi_malregistry-main/zeubilamouche/0.1.4/zeubilamouche-0.1.4-py3-none-any.tar.gz']
# Reading compressed file: pypi_malregistry-main/zeubilamouche/0.1.4/zeubilamouche-0.1.4-py3-none-any.tar.gz
# No setup.py found in pypi_malregistry-main/zeubilamouche/0.1.4/zeubilamouche-0.1.4-py3-none-any.tar.gz
# Version folders found in pypi_malregistry-main/zhpt1cscoe/: ['pypi_malregistry-main/zhpt1cscoe/0.0.1/']
# Compressed files found in pypi_malregistry-main/zhpt1cscoe/0.0.1/: ['pypi_malregistry-main/zhpt1cscoe/0.0.1/zhpt1cscoe-0.0.1-py3-none-any.tar.gz']
# Reading compressed file: pypi_malregistry-main/zhpt1cscoe/0.0.1/zhpt1cscoe-0.0.1-py3-none-any.tar.gz
# No setup.py found in pypi_malregistry-main/zhpt1cscoe/0.0.1/zhpt1cscoe-0.0.1-py3-none-any.tar.gz
# Version folders found in pypi_malregistry-main/zlibsrc/: ['pypi_malregistry-main/zlibsrc/0.0.1/']
# Compressed files found in pypi_malregistry-main/zlibsrc/0.0.1/: ['pypi_malregistry-main/zlibsrc/0.0.1/zlibsrc-0.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/zlibsrc/0.0.1/zlibsrc-0.0.1.tar.gz
# Found setup.py at: zlibsrc-0.0.1/setup.py
# Version folders found in pypi_malregistry-main/znomig/: ['pypi_malregistry-main/znomig/1.0.0/']
# Compressed files found in pypi_malregistry-main/znomig/1.0.0/: ['pypi_malregistry-main/znomig/1.0.0/znomig-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/znomig/1.0.0/znomig-1.0.0.tar.gz
# Found setup.py at: znomig-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/zoom-pyutils/: ['pypi_malregistry-main/zoom-pyutils/7.0.0/']
# Compressed files found in pypi_malregistry-main/zoom-pyutils/7.0.0/: ['pypi_malregistry-main/zoom-pyutils/7.0.0/zoom-pyutils-7.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/zoom-pyutils/7.0.0/zoom-pyutils-7.0.0.tar.gz
# Found setup.py at: zoom-pyutils-7.0.0/setup.py
# Version folders found in pypi_malregistry-main/zorosnitro/: ['pypi_malregistry-main/zorosnitro/1.0/']
# Compressed files found in pypi_malregistry-main/zorosnitro/1.0/: ['pypi_malregistry-main/zorosnitro/1.0/zorosnitro-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/zorosnitro/1.0/zorosnitro-1.0.tar.gz
# Found setup.py at: zorosnitro-1.0.tar.gz/setup.py
# Version folders found in pypi_malregistry-main/zproxy/: ['pypi_malregistry-main/zproxy/1.0/']
# Compressed files found in pypi_malregistry-main/zproxy/1.0/: ['pypi_malregistry-main/zproxy/1.0/zproxy-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/zproxy/1.0/zproxy-1.0.tar.gz
# Found setup.py at: zproxy-1.0/setup.py
# Version folders found in pypi_malregistry-main/zproxy2/: ['pypi_malregistry-main/zproxy2/1.0/']
# Compressed files found in pypi_malregistry-main/zproxy2/1.0/: ['pypi_malregistry-main/zproxy2/1.0/zproxy2-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/zproxy2/1.0/zproxy2-1.0.tar.gz
# Found setup.py at: zproxy2-1.0/setup.py
# Version folders found in pypi_malregistry-main/ztasimb/: ['pypi_malregistry-main/ztasimb/1.0.0/']
# Compressed files found in pypi_malregistry-main/ztasimb/1.0.0/: ['pypi_malregistry-main/ztasimb/1.0.0/ztasimb-1.0.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/ztasimb/1.0.0/ztasimb-1.0.0.tar.gz
# Found setup.py at: ztasimb-1.0.0/setup.py
# Version folders found in pypi_malregistry-main/zuppa/: ['pypi_malregistry-main/zuppa/0.0.1/', 'pypi_malregistry-main/zuppa/0.0.2/']
# Compressed files found in pypi_malregistry-main/zuppa/0.0.1/: ['pypi_malregistry-main/zuppa/0.0.1/zuppa-0.0.1-py3-none-any.tar.gz']
# Reading compressed file: pypi_malregistry-main/zuppa/0.0.1/zuppa-0.0.1-py3-none-any.tar.gz
# No setup.py found in pypi_malregistry-main/zuppa/0.0.1/zuppa-0.0.1-py3-none-any.tar.gz
# Compressed files found in pypi_malregistry-main/zuppa/0.0.2/: ['pypi_malregistry-main/zuppa/0.0.2/zuppa-0.0.2-py3-none-any.tar.gz']
# Reading compressed file: pypi_malregistry-main/zuppa/0.0.2/zuppa-0.0.2-py3-none-any.tar.gz
# No setup.py found in pypi_malregistry-main/zuppa/0.0.2/zuppa-0.0.2-py3-none-any.tar.gz
# Version folders found in pypi_malregistry-main/zwhrce/: ['pypi_malregistry-main/zwhrce/0.0.1/']
# Compressed files found in pypi_malregistry-main/zwhrce/0.0.1/: ['pypi_malregistry-main/zwhrce/0.0.1/zwhrce-0.0.1.tar.gz']
# Reading compressed file: pypi_malregistry-main/zwhrce/0.0.1/zwhrce-0.0.1.tar.gz
# Found setup.py at: zwhrce-0.0.1.tar.gz/setup.py
# Version folders found in pypi_malregistry-main/zydnitro/: ['pypi_malregistry-main/zydnitro/1.0/']
# Compressed files found in pypi_malregistry-main/zydnitro/1.0/: ['pypi_malregistry-main/zydnitro/1.0/zydnitro-1.0.tar.gz']
# Reading compressed file: pypi_malregistry-main/zydnitro/1.0/zydnitro-1.0.tar.gz
# Found setup.py at: zydnitro-1.0.tar.gz/setup.py
# Version folders found in pypi_malregistry-main/zyqnuutupjerllnbxaeq/: ['pypi_malregistry-main/zyqnuutupjerllnbxaeq/0.0.1/']
# Compressed files found in pypi_malregistry-main/zyqnuutupjerllnbxaeq/0.0.1/: ['pypi_malregistry-main/zyqnuutupjerllnbxaeq/0.0.1/zyqnuutupjerllnbxaeq-0.0.1-py3-none-any.tar.gz']
# Reading compressed file: pypi_malregistry-main/zyqnuutupjerllnbxaeq/0.0.1/zyqnuutupjerllnbxaeq-0.0.1-py3-none-any.tar.gz
# No setup.py found in pypi_malregistry-main/zyqnuutupjerllnbxaeq/0.0.1/zyqnuutupjerllnbxaeq-0.0.1-py3-none-any.tar.gz
#
# Summary:
# Total outer folders found: 1
# Total package folders found: 6110
# Total version folders found: 7147
# Total compressed files found: 7131
# Total no compressed files found: 16
# Total inner compressed files read: 7131
# Total setup.py files found: 6487
# Total no setup.py files found: 637

# %% [markdown]
# ## Collect Malicious Packages Details From Files

# %%
import zipfile
import tarfile
import io
import pandas as pd
import configparser
import re

# Define illegal characters for Excel and a function to clean them
ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]')

def remove_illegal_characters(value):
    """Removes illegal characters and converts non-string values to string."""
    if isinstance(value, str):
        return ILLEGAL_CHARACTERS_RE.sub('', value)
    return str(value)  # Ensure all values are strings for Excel compatibility

# Function to safely decode file contents with fallback encoding
def safe_decode(byte_data):
    try:
        return byte_data.decode('utf-8')
    except UnicodeDecodeError:
        # Fallback to latin-1 or another encoding if utf-8 fails
        return byte_data.decode('latin-1')

# Function to check if file content is valid for configparser
def is_valid_config(content):
    try:
        config = configparser.ConfigParser()
        config.read_string(content)
        return True
    except configparser.MissingSectionHeaderError:
        return False

# Extract package name and version from filename if PKG-INFO is missing
def extract_name_version_from_filename(tar_package_name):
    try:
        filename = tar_package_name.split('/')[-1].replace('.tar.gz', '')
        name, version = filename.split('-')[0], filename.split('-')[1]
        return name, version
    except IndexError:
        return '', ''  # Default to empty if the filename structure is not as expected

# Function to process and extract metadata from various files, including the new structure
def extract_metadata(tar, tar_package_name):
    # Try to get package name and version from file name first
    default_name, default_version = extract_name_version_from_filename(tar_package_name)

    metadata = {
        "Path": tar_package_name,  # Include the path of the package as a column
        "Malicious Package Name": default_name,  # Default from filename
        "Malicious Package Version": default_version,  # Default from filename
        "PKG-INFO": 'N',  # Default to not found
        "Metadata-Version": '',
        "Summary": '',
        "Author": '',
        "Author-email": '',
        "License": '',
        "Home-page": '',  # Add Home-page to the metadata
        "Keywords": '',
        "Description": '',
        "Platform": '',
        "Classifier": '',
        "Documentation": '',
        "Description-Content-Type": '',
        "Setup.py Exists": 'N',
        "setup.py": '',
        "README.md Exists": 'N',
        "README Content": '',
        "LICENSE Exists": 'N',
        "MANIFEST.in Exists": 'N',
        "requirements.txt Exists": 'N',
        "setup.cfg Exists": 'N',
        "tag_build": '',
        "tag_date": '',
        "pyproject.toml Exists": 'N',
        "pyproject.toml Content": '',
        "dependency links": '',
        "requires": '',
        "SOURCES": '',
        "top_level": '',
        "my_package Exists": 'N',
        "subpackage Exists": 'N',
        "modules": [],
        "tests Exists": 'N',
        "test_modules": [],
        "Reason for Skipping": ''  # Column to hold skip reason, initially empty
    }

    # Process PKG-INFO file
    pkg_info_path = [name for name in tar.getnames() if 'PKG-INFO' in name]
    if pkg_info_path:
        metadata["PKG-INFO"] = 'Y'
        pkg_info_file = tar.extractfile(pkg_info_path[0])
        if pkg_info_file:  # Ensure the file is not None
            try:
                pkg_info = safe_decode(pkg_info_file.read())  # Use safe_decode
                for line in pkg_info.splitlines():
                    if line.startswith("Name:"):
                        metadata["Malicious Package Name"] = line.split(":")[1].strip()
                    elif line.startswith("Version:"):
                        metadata["Malicious Package Version"] = line.split(":")[1].strip()
                    elif line.startswith("Metadata-Version:"):
                        metadata["Metadata-Version"] = line.split(":")[1].strip()
                    elif line.startswith("Summary:"):
                        metadata["Summary"] = line.split(":")[1].strip()
                    elif line.startswith("Author:"):
                        metadata["Author"] = line.split(":")[1].strip()
                    elif line.startswith("Author-email:"):
                        metadata["Author-email"] = line.split(":")[1].strip()
                    elif line.startswith("License:"):
                        metadata["License"] = line.split(":")[1].strip()
                    elif line.startswith("Home-page:"):
                        metadata["Home-page"] = line.split(":")[1].strip()  # Extract Home-page
                    elif line.startswith("Keywords:"):
                        metadata["Keywords"] = line.split(":")[1].strip()
                    elif line.startswith("Description:"):
                        metadata["Description"] = line.split(":")[1].strip()
                    elif line.startswith("Platform:"):
                        metadata["Platform"] = line.split(":")[1].strip()
                    elif line.startswith("Classifier:"):
                        metadata["Classifier"] = line.split(":")[1].strip()
                    elif line.startswith("Documentation:"):
                        metadata["Documentation"] = line.split(":")[1].strip()
                    elif line.startswith("Description-Content-Type:"):
                        metadata["Description-Content-Type"] = line.split(":")[1].strip()
            except Exception as e:
                print(f"Error reading PKG-INFO: {e}")
    
    # Process setup.py
    setup_py_path = [name for name in tar.getnames() if 'setup.py' in name]
    if setup_py_path:
        setup_py_file = tar.extractfile(setup_py_path[0])
        if setup_py_file:
            metadata["Setup.py Exists"] = 'Y'
            setup_py_content = safe_decode(setup_py_file.read())  # Use safe_decode
            metadata["setup.py"] = setup_py_content  # Store full content if needed
            if not metadata["Malicious Package Name"]:  # If Name wasn't found in PKG-INFO, try extracting from setup.py
                for line in setup_py_content.splitlines():
                    if "name=" in line:
                        metadata["Malicious Package Name"] = line.split('=')[1].strip().replace('"', '').replace("'", "")
                    if "version=" in line:
                        metadata["Version"] = line.split('=')[1].strip().replace('"', '').replace("'", "")

    # Process README.md
    readme_path = [name for name in tar.getnames() if 'README.md' in name]
    if readme_path:
        readme_file = tar.extractfile(readme_path[0])
        if readme_file:
            metadata["README.md Exists"] = 'Y'
            metadata["README Content"] = safe_decode(readme_file.read())  # Use safe_decode

    # Process LICENSE
    license_path = [name for name in tar.getnames() if 'LICENSE' in name]
    if license_path:
        license_file = tar.extractfile(license_path[0])
        if license_file:
            metadata["LICENSE Exists"] = 'Y'

    # Process MANIFEST.in
    manifest_path = [name for name in tar.getnames() if 'MANIFEST.in' in name]
    if manifest_path:
        manifest_file = tar.extractfile(manifest_path[0])
        if manifest_file:
            metadata["MANIFEST.in Exists"] = 'Y'

    # Process requirements.txt
    requirements_path = [name for name in tar.getnames() if 'requirements.txt' in name]
    if requirements_path:
        requirements_file = tar.extractfile(requirements_path[0])
        if requirements_file:
            metadata["requirements.txt Exists"] = 'Y'

    # Process setup.cfg and extract tag_build and tag_date using configparser
    setup_cfg_path = [name for name in tar.getnames() if 'setup.cfg' in name]
    if setup_cfg_path:
        setup_cfg_file = tar.extractfile(setup_cfg_path[0])
        if setup_cfg_file:
            metadata["setup.cfg Exists"] = 'Y'
            setup_cfg_content = safe_decode(setup_cfg_file.read())  # Use safe_decode

            # Ensure setup.cfg contains valid sections before parsing
            if is_valid_config(setup_cfg_content):
                config = configparser.ConfigParser()
                config.read_string(setup_cfg_content)

                # Attempt to extract tag_build and tag_date from the setup.cfg
                if 'egg_info' in config:
                    metadata["tag_build"] = config.get('egg_info', 'tag_build', fallback='')
                    metadata["tag_date"] = config.get('egg_info', 'tag_date', fallback='')

    # Process pyproject.toml
    pyproject_toml_path = [name for name in tar.getnames() if 'pyproject.toml' in name]
    if pyproject_toml_path:
        pyproject_toml_file = tar.extractfile(pyproject_toml_path[0])
        if pyproject_toml_file:
            metadata["pyproject.toml Exists"] = 'Y'
            metadata["pyproject.toml Content"] = safe_decode(pyproject_toml_file.read())  # Use safe_decode

    # Process egg-info files (dependency_links, requires, SOURCES, etc.)
    egg_info_files = [name for name in tar.getnames() if 'egg-info/' in name]
    for egg_file in egg_info_files:
        egg_info_file = tar.extractfile(egg_file)
        if egg_info_file:
            if 'dependency_links.txt' in egg_file:
                metadata["dependency links"] = safe_decode(egg_info_file.read()).strip()  # Use safe_decode
            elif 'requires.txt' in egg_file:
                metadata["requires"] = safe_decode(egg_info_file.read()).strip()  # Use safe_decode
            elif 'SOURCES.txt' in egg_file:
                metadata["SOURCES"] = safe_decode(egg_info_file.read()).strip()  # Use safe_decode
            elif 'top_level.txt' in egg_file:
                metadata["top_level"] = safe_decode(egg_info_file.read()).strip()  # Use safe_decode

    # Check for the existence of my_package/
    package_dir = [name for name in tar.getnames() if 'my_package/' in name]
    if package_dir:
        metadata["my_package Exists"] = 'Y'
        # Check for subpackage
        subpackage_dir = [name for name in tar.getnames() if 'my_package/subpackage/' in name]
        if subpackage_dir:
            metadata["subpackage Exists"] = 'Y'

        # Get modules inside my_package
        module_files = [name for name in tar.getnames() if 'my_package/' in name and name.endswith('.py')]
        metadata["modules"] = module_files

    # Check for the existence of tests/
    test_dir = [name for name in tar.getnames() if 'tests/' in name]
    if test_dir:
        metadata["tests Exists"] = 'Y'
        # Get test modules inside tests/
        test_files = [name for name in tar.getnames() if 'tests/' in name and name.endswith('.py')]
        metadata["test_modules"] = test_files

    return metadata

def count_setup_py_in_nested_zip(zip_file_path):
    data = []  # Store data for each package
    skip_count = 0  # Counter for skipped packages
    with zipfile.ZipFile(zip_file_path, 'r') as outer_zip:
        # List the contents of the outer zip to find the only folder (FolderName)
        folder_name = [name for name in outer_zip.namelist() if name.endswith('/')][0]
        print(f"Found outer folder: {folder_name}")
        
        # List the folders directly under the outer folder (PackageNameFolders)
        package_folders = [name for name in outer_zip.namelist() 
                           if name.startswith(folder_name) 
                           and name.endswith('/') 
                           and name.count('/') == folder_name.count('/') + 1]
        
        # Iterate through PackageNameFolders to find VersionFolders and tar.gz files
        for package_folder in package_folders:
            version_folders = [name for name in outer_zip.namelist() 
                               if name.startswith(package_folder) 
                               and name.endswith('/') 
                               and name != package_folder]
            
            for version_folder in version_folders:
                # Check for a .tar.gz file within the VersionFolder
                tar_files = [name for name in outer_zip.namelist() if name.startswith(version_folder) and name.endswith('.tar.gz')]
                
                if tar_files:
                    tar_package_name = tar_files[0]
                    print(f"Reading inner tar file: {tar_package_name}")
                    
                    try:
                        # Now, read the inner tar.gz file
                        with outer_zip.open(tar_package_name) as inner_tar_file:
                            # Extract and read the tar.gz file in memory
                            with tarfile.open(fileobj=io.BytesIO(inner_tar_file.read()), mode='r') as tar:
                                # Extract metadata and store it
                                metadata = extract_metadata(tar, tar_package_name)
                                data.append(metadata)
                    except (tarfile.ReadError, EOFError, UnicodeDecodeError) as e:
                        print(f"Skipping file {tar_package_name}, encountered an error during processing.")
                        # Add entry to data with the skip reason
                        name, version = extract_name_version_from_filename(tar_package_name)
                        data.append({
                            "Malicious Package Name": name,
                            "Malicious Package Version": version,
                            "Path": tar_package_name,
                            "Reason for Skipping": str(e)
                        })
                        skip_count += 1  # Increment the skip counter

    # Create DataFrame, remove illegal characters, and save to Excel
    df = pd.DataFrame(data)
    print(f"DataFrame shape before export: {df.shape}")
    
    # Check for missing or empty columns
    missing_columns = df.columns[df.isna().all()].tolist()
    print(f"Empty columns: {missing_columns}")

    # Ensure all columns are included
    df = df.apply(lambda x: x.map(remove_illegal_characters))  # Clean illegal characters
    
    # Convert the DataFrame to a list of tuples
    df_list = df.values.tolist()

    # Sort the list using sorted(), case-insensitive for the first column (Package Name)
    df_list_sorted = sorted(df_list, key=lambda x: x[0].lower())

    # Convert the sorted list back to a DataFrame
    df_sorted = pd.DataFrame(df_list_sorted, columns=df.columns)

    # Write the sorted DataFrame to an Excel file
    df_sorted.to_excel('MaliciousPackagesDetailsFromFiles.xlsx', index=False)

    print(f"Metadata extracted and saved to MaliciousPackageMetadata.xlsx with {df_sorted.shape[1]} columns")
    print(f"Total packages: {df_sorted.shape[0]}")  # Print total package count
    print(f"Total corrupted packages: {skip_count}")  # Print skipped package count
    print(f"Metadata found packages: {df_sorted.shape[0]-skip_count}")  # Print metadata found package count

# Path to your zip file
zip_file_path = 'D:/Final Version/Dataset/pypi_malregistry.zip'
count_setup_py_in_nested_zip(zip_file_path)
# Out:
# Found outer folder: pypi_malregistry-main/
# Reading inner tar file: pypi_malregistry-main/10Cent10/999.0.4/10Cent10-999.0.4.tar.gz
# Reading inner tar file: pypi_malregistry-main/10Cent11/999.0.4/10Cent11-999.0.4.tar.gz
# Reading inner tar file: pypi_malregistry-main/11cent/999.0.0/11Cent-999.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/11cent/999.0.1/11Cent-999.0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/11cent/999.0.2/11Cent-999.0.2.tar.gz
# Reading inner tar file: pypi_malregistry-main/11cent/999.0.3/11Cent-999.0.3.tar.gz
# Reading inner tar file: pypi_malregistry-main/11cent/999.0.4/11Cent-999.0.4.tar.gz
# Reading inner tar file: pypi_malregistry-main/12cent/999.0.0/12Cent-999.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/12cent/999.0.1/12Cent-999.0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/1337c/4.4.7/1337c-4.4.7.tar.gz
# Reading inner tar file: pypi_malregistry-main/1337test/1/1337test-1.tar.gz
# Reading inner tar file: pypi_malregistry-main/1337z/4.4.7/1337z-4.4.7.tar.gz
# Reading inner tar file: pypi_malregistry-main/13cent/999.0.1/13Cent-999.0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/13cent/999.0.2/13Cent-999.0.2.tar.gz
# Reading inner tar file: pypi_malregistry-main/14cent/999.0.1/14Cent-999.0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/15cent/999.0.1/15Cent-999.0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/16cent/999.0.1/16Cent-999.0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/1inch/8.6/1inch-8.6.tar.gz
# Reading inner tar file: pypi_malregistry-main/1inch/8.7/1inch-8.7.tar.gz
# Reading inner tar file: pypi_malregistry-main/1inch/8.9/1inch-8.9.tar.gz
# Reading inner tar file: pypi_malregistry-main/2022-requests/3.0.0/2022-requests-3.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/282828282828282828/0.0.0/282828282828282828-0.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/3m-promo-link-gen/1.0/3m-promo-link-gen-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/3web-py/3web.py-1.0.0/3web.py-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/3web/1.0.0/3web-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/4123/1/4123-1-py3-none-any.tar.gz
# Skipping file pypi_malregistry-main/4123/1/4123-1-py3-none-any.tar.gz, encountered an error during processing.
# Reading inner tar file: pypi_malregistry-main/90456984689490856/0/90456984689490856-0-py3-none-any.tar.gz
# Skipping file pypi_malregistry-main/90456984689490856/0/90456984689490856-0-py3-none-any.tar.gz, encountered an error during processing.
# Reading inner tar file: pypi_malregistry-main/AadhaarCrypt/1.0/AadhaarCrypt-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/Ailyboostbot/1.0/Ailyboostbot-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/Ailynitro/1.0/Ailynitro-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeaitifulSoop/1.0.0/BeaitifulSoop-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeaotifulSoup/1.0.0/BeaotifulSoup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeaufifulSoup/1.0.0/BeaufifulSoup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifilSoop/1.0.0/BeautifilSoop-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifilSoup/1.0.0/BeautifilSoup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifolSoup/1.0.0/BeautifolSoup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifoulSoup/1.0.0/BeautifoulSoup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifulSoop/1.0.0/BeautifulSoop-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifulSoul/1.0.0/BeautifulSoul-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifulSoup-new/3.0.0/BeautifulSoup-new-3.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifulSoupo/1.0.0/BeautifulSoupo-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifullSoop/1.0.0/BeautifullSoop-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautifullSooup/1.0.0/BeautifullSooup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautySoup/1.0.0/BeautySoup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeautyfulSoup/1.0.0/BeautyfulSoup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/BeuatiflSoup/1.0.0/BeuatiflSoup-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/B
0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/yfinnance/0.1/yfinnance-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/yfinnce/0.1/yfinnce-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/yfnance/0.1/yfnance-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/yfniance/0.1/yfniance-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/ygame/0.1/ygame-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/yiffparty/0.01/yiffparty-0.01.tar.gz
# Reading inner tar file: pypi_malregistry-main/yiffparty/0.02/yiffparty-0.02.tar.gz
# Reading inner tar file: pypi_malregistry-main/yiffparty/0.03/yiffparty-0.03.tar.gz
# Reading inner tar file: pypi_malregistry-main/yiffparty/0.04/yiffparty-0.04.tar.gz
# Reading inner tar file: pypi_malregistry-main/yiffparty/0.05/yiffparty-0.05.tar.gz
# Reading inner tar file: pypi_malregistry-main/yinance/4.5.2/yinance-4.5.2.tar.gz
# Reading inner tar file: pypi_malregistry-main/yinstaller/4.5.2/yinstaller-4.5.2.tar.gz
# Reading inner tar file: pypi_malregistry-main/ymongo/4.4.7/ymongo-4.4.7.tar.gz
# Reading inner tar file: pypi_malregistry-main/yocolor/0.4.6/yocolor-0.4.6.tar.gz
# Reading inner tar file: pypi_malregistry-main/yohewoasaw/0.0.0/yohewoasaw-0.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/youhans/1.0.0/youhans-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/youtube-new/2.2.1/youtube-new-2.2.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/ypcodestyle/0.1/ypcodestyle-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/yper/0.1/yper-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/ypinstaller/0.1/ypinstaller-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/ypsocks/0.1/ypsocks-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/ypthon-binance/0.1/ypthon-binance-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/yptt/4.4.7/yptt-4.4.7.tar.gz
# Reading inner tar file: pypi_malregistry-main/ysocks/0.1/ysocks-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/ython-binance/0.1/ython-binance-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/ytorch/0.1/ytorch-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/yvper/0.1/yvper-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/ywin32/4.5.2/ywin32-4.5.2.tar.gz
# Reading inner tar file: pypi_malregistry-main/yyfinance/0.1/yyfinance-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/zafira/0.1/zafira-0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/zefkopzekfo/0.0.1/zefkopzekfo-0.0.1-py3-none-any.tar.gz
# Skipping file pypi_malregistry-main/zefkopzekfo/0.0.1/zefkopzekfo-0.0.1-py3-none-any.tar.gz, encountered an error during processing.
# Reading inner tar file: pypi_malregistry-main/zelixnitro/1.0/zelixnitro-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/zeubilamouche/0.1.4/zeubilamouche-0.1.4-py3-none-any.tar.gz
# Skipping file pypi_malregistry-main/zeubilamouche/0.1.4/zeubilamouche-0.1.4-py3-none-any.tar.gz, encountered an error during processing.
# Reading inner tar file: pypi_malregistry-main/zhpt1cscoe/0.0.1/zhpt1cscoe-0.0.1-py3-none-any.tar.gz
# Skipping file pypi_malregistry-main/zhpt1cscoe/0.0.1/zhpt1cscoe-0.0.1-py3-none-any.tar.gz, encountered an error during processing.
# Reading inner tar file: pypi_malregistry-main/zlibsrc/0.0.1/zlibsrc-0.0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/znomig/1.0.0/znomig-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/zoom-pyutils/7.0.0/zoom-pyutils-7.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/zorosnitro/1.0/zorosnitro-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/zproxy/1.0/zproxy-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/zproxy2/1.0/zproxy2-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/ztasimb/1.0.0/ztasimb-1.0.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/zuppa/0.0.1/zuppa-0.0.1-py3-none-any.tar.gz
# Skipping file pypi_malregistry-main/zuppa/0.0.1/zuppa-0.0.1-py3-none-any.tar.gz, encountered an error during processing.
# Reading inner tar file: pypi_malregistry-main/zuppa/0.0.2/zuppa-0.0.2-py3-none-any.tar.gz
# Skipping file pypi_malregistry-main/zuppa/0.0.2/zuppa-0.0.2-py3-none-any.tar.gz, encountered an error during processing.
# Reading inner tar file: pypi_malregistry-main/zwhrce/0.0.1/zwhrce-0.0.1.tar.gz
# Reading inner tar file: pypi_malregistry-main/zydnitro/1.0/zydnitro-1.0.tar.gz
# Reading inner tar file: pypi_malregistry-main/zyqnuutupjerllnbxaeq/0.0.1/zyqnuutupjerllnbxaeq-0.0.1-py3-none-any.tar.gz
# Skipping file pypi_malregistry-main/zyqnuutupjerllnbxaeq/0.0.1/zyqnuutupjerllnbxaeq-0.0.1-py3-none-any.tar.gz, encountered an error during processing.
# DataFrame shape before export: (7127, 38)
# Empty columns: []
# Metadata extracted and saved to MaliciousPackageMetadata.xlsx with 38 columns
# Total packages: 7127
# Total corrupted packages: 521
# Metadata found packages: 6606

# %% [markdown]
# **----End of Step 2----**
